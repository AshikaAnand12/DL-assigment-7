# %% [markdown]
# <a href="https://colab.research.google.com/github/AshikaAnand12/DL-assigment-7/blob/main/LSTM_RNN_in_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # One-to-One LSTM
# [Source](https://machinelearningmastery.com/timedistributed-layer-for-long-short-term-memory-networks-in-python/)
#
#
# [Second source](https://stackoverflow.com/questions/52138290/how-can-we-define-one-to-one-one-to-many-many-to-one-and-many-to-many-lstm-ne)

# %%
from numpy import array
length = 5
seq = array([i/float(length) for i in range(length)])
print(seq)
# Out:
# [0.  0.2 0.4 0.6 0.8]

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
# prepare sequence
length = 5
seq = array([i/float(length) for i in range(length)])
X = seq.reshape(len(seq), 1, 1)
y = seq.reshape(len(seq), 1)
# define LSTM configuration
n_neurons = length
n_batch = length
n_epoch = 1000
# create LSTM
model = Sequential()
model.add(LSTM(n_neurons, input_shape=(1, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
print(model.summary())
# train LSTM
model.fit(X, y, epochs=n_epoch, batch_size=n_batch, verbose=2)
# evaluate
result = model.predict(X, batch_size=n_batch, verbose=0)
for value in result:
    print('%.1f' % value)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 5)                 140
#
#  dense (Dense)               (None, 1)                 6
#
# ...
# Total params: 146
# Trainable params: 146
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/1000
# 1/1 - 2s - loss: 0.2342 - 2s/epoch - 2s/step
# Epoch 2/1000
# 1/1 - 0s - loss: 0.2325 - 7ms/epoch - 7ms/step
# Epoch 3/1000
# 1/1 - 0s - loss: 0.2309 - 8ms/epoch - 8ms/step
# Epoch 4/1000
# 1/1 - 0s - loss: 0.2293 - 9ms/epoch - 9ms/step
# Epoch 5/1000
# 1/1 - 0s - loss: 0.2277 - 8ms/epoch - 8ms/step
# Epoch 6/1000
# 1/1 - 0s - loss: 0.2261 - 6ms/epoch - 6ms/step
# Epoch 7/1000
# 1/1 - 0s - loss: 0.2245 - 5ms/epoch - 5ms/step
# Epoch 8/1000
# 1/1 - 0s - loss: 0.2229 - 8ms/epoch - 8ms/step
# Epoch 9/1000
# 1/1 - 0s - loss: 0.2213 - 5ms/epoch - 5ms/step
# ...

# %% [markdown]
# # Many to One
# [Source](https://www.programcreek.com/python/example/89689/keras.layers.RepeatVector)

# %%
from numpy import array
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
# prepare sequence
length = 5
seq = array([i/float(length) for i in range(length)])
X = seq.reshape(1, length, 1)
y = seq.reshape(1, length)
# define LSTM configuration
n_neurons = length
n_batch = 1
n_epoch = 500
# create LSTM
model = Sequential()
model.add(LSTM(n_neurons, input_shape=(length, 1)))
model.add(Dense(length))
model.compile(loss='mean_squared_error', optimizer='adam')
print(model.summary())
# train LSTM
model.fit(X, y, epochs=n_epoch, batch_size=n_batch, verbose=2)
# evaluate
result = model.predict(X, batch_size=n_batch, verbose=0)
for value in result[0,:]:
	print('%.1f' % value)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_3 (LSTM)               (None, 5)                 140
#
#  dense_3 (Dense)             (None, 5)                 30
#
# ...
# Total params: 170
# Trainable params: 170
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/500
# 1/1 - 3s - loss: 0.2534 - 3s/epoch - 3s/step
# Epoch 2/500
# 1/1 - 0s - loss: 0.2513 - 7ms/epoch - 7ms/step
# Epoch 3/500
# 1/1 - 0s - loss: 0.2492 - 9ms/epoch - 9ms/step
# Epoch 4/500
# 1/1 - 0s - loss: 0.2471 - 8ms/epoch - 8ms/step
# Epoch 5/500
# 1/1 - 0s - loss: 0.2450 - 9ms/epoch - 9ms/step
# Epoch 6/500
# 1/1 - 0s - loss: 0.2430 - 9ms/epoch - 9ms/step
# Epoch 7/500
# 1/1 - 0s - loss: 0.2411 - 8ms/epoch - 8ms/step
# Epoch 8/500
# 1/1 - 0s - loss: 0.2391 - 12ms/epoch - 12ms/step
# Epoch 9/500
# 1/1 - 0s - loss: 0.2372 - 11ms/epoch - 11ms/step
# ...

# %% [markdown]
# # Many to Many

# %%
from numpy import array
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import TimeDistributed
from keras.layers import LSTM
# prepare sequence
length = 5
seq = array([i/float(length) for i in range(length)])
X = seq.reshape(1, length, 1)
y = seq.reshape(1, length, 1)
# define LSTM configuration
n_neurons = length
n_batch = 1
n_epoch = 1000
# create LSTM
model = Sequential()
model.add(LSTM(n_neurons, input_shape=(length, 1), return_sequences=True))
model.add(TimeDistributed(Dense(1)))
model.compile(loss='mean_squared_error', optimizer='adam')
print(model.summary())
# train LSTM
model.fit(X, y, epochs=n_epoch, batch_size=n_batch, verbose=2)
# evaluate
result = model.predict(X, batch_size=n_batch, verbose=0)
for value in result[0,:,0]:
	print('%.1f' % value)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_5 (LSTM)               (None, 5, 5)              140
#
#  time_distributed (TimeDistr  (None, 5, 1)             6
#  ibuted)
#
# ...
# Total params: 146
# Trainable params: 146
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/1000
# 1/1 - 2s - loss: 0.3338 - 2s/epoch - 2s/step
# Epoch 2/1000
# 1/1 - 0s - loss: 0.3298 - 8ms/epoch - 8ms/step
# Epoch 3/1000
# 1/1 - 0s - loss: 0.3259 - 9ms/epoch - 9ms/step
# Epoch 4/1000
# 1/1 - 0s - loss: 0.3220 - 7ms/epoch - 7ms/step
# Epoch 5/1000
# 1/1 - 0s - loss: 0.3181 - 7ms/epoch - 7ms/step
# Epoch 6/1000
# 1/1 - 0s - loss: 0.3143 - 7ms/epoch - 7ms/step
# Epoch 7/1000
# 1/1 - 0s - loss: 0.3104 - 7ms/epoch - 7ms/step
# Epoch 8/1000
# 1/1 - 0s - loss: 0.3067 - 8ms/epoch - 8ms/step
# Epoch 9/1000
# ...
